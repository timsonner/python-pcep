# %%
distros = ["debian", "rhel", "mx", "kali", "ubuntu"]

# %%
best_distro = distros

# %%
best_distro is distros
# Out:
# True

# %%
print(best_distro)
# Out:
# ['debian', 'rhel', 'mx', 'kali', 'ubuntu']

# %%
best_distro = distros[0:1]

# %%
print(best_distro[0])
# Out:
# debian

# %%
counter = 0

# %%
for ix in range(len(distros)):
    print(distros[ix], end=' ' )
    distros[ix] = counter
    counter += 1
for ix in range(len(distros)):
    print(distros[ix],end=' ')
# Out:
# debian rhel mx kali ubuntu 0 1 2 3 4

# %%
distros = ["debian", "rhel", "mx", "kali", "ubuntu"]

# %%
distros.insert(0, "arch")

# %%
print(distros)
# Out:
# ['arch', 'debian', 'rhel', 'mx', 'kali', 'ubuntu']

# %%
print("debian" in distros, "arch" not in distros)
# Out:
# True False

# %%
debian_derivatives = [distro for distro in distros if distro[0] == "m" or distro[0] == "k" or distro[0] == "u"]

# %%
print(debian_derivatives)
# Out:
# ['mx', 'kali', 'ubuntu']

# %%
rhel_derivatives = [distro for distro in distros if distro[0] == "r"]

# %%
rhel_derivatives.append("oracle")

# %%
rhel_derivatives.extend("centos")

# %%
rhel_derivatives += ["rocky", "alma"]

# %%
evens = [num for num in range(10) if num % 2 == 0]

# %%
print(evens)
# Out:
# [0, 2, 4, 6, 8]

# %%
odds = [num for num in range(10) if num %2 != 0]

# %%
print(odds)
# Out:
# [1, 3, 5, 7, 9]
