# %%
distro_inits = {
    "arch": "systemd",
    "debian": "systemd",
    "ubuntu": "systemd",
    "fedora": "systemd",
    "rhel": "systemd",
    "centos_stream": "systemd",
    "opensuse": "systemd",
    "openmandriva": "systemd",
    "alma_linux": "systemd",
    "rocky_linux": "systemd",
    "artix": ["openrc", "runit", "s6", "dinit"],
    "devuan": ["sysvinit", "openrc", "runit"],
    "gentoo": "openrc",
    "alpine": "openrc",
    "void": "runit",
    "slackware": "bsd-style init",
    "antiX": ["sysvinit", "runit"],
}

# %%
dir(init_systems)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
print(distro_inits.keys())
# Out:
# dict_keys(['arch', 'debian', 'ubuntu', 'fedora', 'rhel', 'centos_stream', 'opensuse', 'openmandriva', 'alma_linux', 'rocky_linux', 'artix', 'devuan', 'gentoo', 'alpine', 'void', 'slackware', 'antiX'])

# %%
init_systems = set(
    init
    for inits in distro_inits.values()
    for init in (inits if isinstance(inits, list) else [inits])
)

# %%
init_systems[1 for init in distro_inits if init.contains("systemd"]
# Out:
# {'bsd-style init', 'dinit', 'openrc', 'runit', 's6', 'systemd', 'sysvinit'}

# %%
print(distro_inits.values())
# Out:
# dict_values(['systemd', 'systemd', 'systemd', 'systemd', 'systemd', 'systemd', 'systemd', 'systemd', 'systemd', 'systemd', ['openrc', 'runit', 's6', 'dinit'], ['sysvinit', 'openrc', 'runit'], 'openrc', 'openrc', 'runit', 'bsd-style init', ['sysvinit', 'runit']])

# %%
systemd_keys = [
    key for key, value in distro_inits.items()
    if (value == "systemd") or (isinstance(value, list) and "systemd" in value)
]

# %%
print(systemd_keys)
# Out:
# ['arch', 'debian', 'ubuntu', 'fedora', 'rhel', 'centos_stream', 'opensuse', 'openmandriva', 'alma_linux', 'rocky_linux']

# %%
print(distro_inits)
# Out:
# {'arch': 'systemd', 'debian': 'systemd', 'ubuntu': 'systemd', 'fedora': 'systemd', 'rhel': 'systemd', 'centos_stream': 'systemd', 'opensuse': 'systemd', 'openmandriva': 'systemd', 'alma_linux': 'systemd', 'rocky_linux': 'systemd', 'artix': ['openrc', 'runit', 's6', 'dinit'], 'devuan': ['sysvinit', 'openrc', 'runit'], 'gentoo': 'openrc', 'alpine': 'openrc', 'void': 'runit', 'slackware': 'bsd-style init', 'antiX': ['sysvinit', 'runit']}

# %%
for key,value in distro_inits.items():
    if value == "systemd":
        print(key)
# Out:
# arch
# debian
# ubuntu
# fedora
# rhel
# centos_stream
# opensuse
# openmandriva
# alma_linux
# rocky_linux

# %%
distro_inits.get("artix")
# Out:
# ['openrc', 'runit', 's6', 'dinit']
