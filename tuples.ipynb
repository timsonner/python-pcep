# %%
distros = "rhel", "alma", "rocky"

# %%
print(type(distros))
# Out:
# <class 'tuple'>

# %%
dir(distros)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
distros += ("arch",)

# %%
print(distros)
# Out:
# ('rhel', 'alma', 'rocky', 'centos', 'arch')

# %%
distros.count("arch")
# Out:
# 1

# %%
distros.index("rocky")
# Out:
# 2

# %%
rhel_distros = distros[:-1]

# %%
print(rhel_distros)
# Out:
# ('rhel', 'alma', 'rocky', 'centos')

# %%
rhel_distros += ("fedora", "oracle")

# %%
print(rhel_distros)
# Out:
# ('rhel', 'alma', 'rocky', 'centos', 'fedora', 'oracle')

# %%
x = tuple(distro for distro in rhel_distros if distro == "fedora")

# %%
type(x)
# Out:
# tuple

# %%
print(x)
# Out:
# ('fedora',)

# %%
s = sorted(rhel_distros)

# %%
print(s)
# Out:
# ['alma', 'centos', 'rhel', 'rocky']
